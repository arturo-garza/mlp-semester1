# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %% [markdown]
# ### Function to save graphs to PDF.

# %%
def save_img(imgs, type_of_image):
    amount_of_imgs = len(imgs)
    for i in range(0,amount_of_imgs):
        imgs[i].tight_layout()
        imgs[i].savefig('2A_'+type_of_image+'_'+str(i)+'.pdf')

# %% [markdown]
# ### Train model and plot stats.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, model_name, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    save_img([fig_1,fig_2], model_name)
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %% [markdown]
# ### Set up data providers.

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider

# Seed a random number generator
seed = 10102016 
rng = np.random.RandomState(seed)
batch_size = 50
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=batch_size, rng=rng)

# %% [markdown]
# ### Run each of the models.
# Run with configuration of only two hidden layers and 100 units per hidden layer.

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

def run_sigmoid():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        SigmoidLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        SigmoidLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_relu():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_LeakyRelu():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        LeakyReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        LeakyReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_ELULayer():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ELULayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ELULayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_SELULayer():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        SELULayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        SELULayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_model(type_of_function):
    switcher = {
        'sigmoid': run_sigmoid, 
        'relu': run_relu,
        'leakyrelu': run_LeakyRelu,
        'elu': run_ELULayer,
        'selu': run_SELULayer
    }
    
    func = switcher.get(type_of_function)
    return func()

# %% [markdown]
# Get the average for the stats and plot the different statistics to compare more easily

# %%
import numpy as np
import matplotlib.pyplot as plt

def average_performance(stats):
    mean_stats = np.mean(stats, axis=0)
    return mean_stats

def plot_mean_error(stats):
    N = len(stats)
    stats_means = np.mean(stats, axis=0)
    stats_std = np.std(stats, axis=0)/(np.sqrt(N))
    print("stats",stats)
    print("stats_means", stats_means)
    print("stats_std", stats_std)

    ind = np.arange(N)  # the x locations for the groups
    width = 0.4       # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(ind, stats_means, width, color='g', yerr=stats_std)

    # add some text for labels, title and axes ticks
    ax.set_ylabel('Error')
    ax.set_title('Error by and function')
    ax.set_xticks(ind + width / 2)
    ax.set_xticklabels(('Sigmoid', 'ReLU', 'LeakyReLU', 'ELU', 'SELU'))

    plt.show()

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser
import matplotlib.pyplot as plt


#Array with all the type of models there are
models_names = ['sigmoid', 'relu','leakyrelu', 'elu', 'selu']

#Array with the mean performance for each function
mean_stats = []

#Run for each of the models
for model_name in models_names:
    model = run_model(model_name)
    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

    #Remember to use notebook=False when you write a script to be run in a terminal
    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, model_name, notebook=True)
    
    mean_stats.append(average_performance(stats))
    
plot_mean_error(mean_stats)
print("stats", stats)
print("mean_stats", mean_stats)
# Out:
# ...
# Epoch 1: 2.8s to complete
#     error(train)=5.41e-01, acc(train)=8.62e-01, error(valid)=5.02e-01, acc(valid)=8.76e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 2.2s to complete
#     error(train)=3.78e-01, acc(train)=8.91e-01, error(valid)=3.49e-01, acc(valid)=8.99e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 5.5s to complete
#     error(train)=3.13e-01, acc(train)=9.11e-01, error(valid)=2.89e-01, acc(valid)=9.17e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 5.0s to complete
#     error(train)=2.82e-01, acc(train)=9.19e-01, error(valid)=2.63e-01, acc(valid)=9.24e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 2.2s to complete
#     error(train)=2.58e-01, acc(train)=9.25e-01, error(valid)=2.41e-01, acc(valid)=9.30e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 2.1s to complete
#     error(train)=2.39e-01, acc(train)=9.30e-01, error(valid)=2.26e-01, acc(valid)=9.35e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 2.1s to complete
# ...

# %% [markdown]
# ### Test deep neural network configuration with the selected activation function and n hidden layers

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)


def run_two_Relu():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_three_Relu():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_four_Relu():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_five_Relu():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_six_Relu():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init),
    ])

def run_seven_Relu():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_eight_Relu():
    return MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

def run_model(amount_of_layers):
    switcher = {
        'two': run_two_Relu, 
        'three': run_three_Relu, 
        'four': run_four_Relu,
        'five': run_five_Relu,
        'six': run_six_Relu,
        'seven': run_seven_Relu,
        'eight': run_eight_Relu
    }
    
    func = switcher.get(amount_of_layers)
    return func()

# %% [markdown]
# ### Run the network for each depth

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser
import matplotlib.pyplot as plt

#Depth of the neural network
model_names = ['two', 'three','four','five','six','seven','eight']
model_err_acc = {}
for model_name in model_names:
    model = run_model(model_name)
    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

    #Remember to use notebook=False when you write a script to be run in a terminal
    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, model_name, notebook=True)
    
    
    model_err_acc[model_name] = stats

for key in model_err_acc.keys():
    print(key, model_err_acc[key])
# Out:
# ...
# Epoch 1: 1.9s to complete
#     error(train)=1.77e-01, acc(train)=9.48e-01, error(valid)=1.71e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 2.1s to complete
#     error(train)=1.21e-01, acc(train)=9.64e-01, error(valid)=1.28e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 2.0s to complete
#     error(train)=8.71e-02, acc(train)=9.75e-01, error(valid)=1.07e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 2.0s to complete
#     error(train)=7.18e-02, acc(train)=9.79e-01, error(valid)=1.03e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 1.8s to complete
#     error(train)=5.51e-02, acc(train)=9.84e-01, error(valid)=9.30e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 1.8s to complete
#     error(train)=5.37e-02, acc(train)=9.84e-01, error(valid)=9.19e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 1.8s to complete
# ...

# %% [markdown]
# ### Run different initialization strategies

# %% [markdown]
# ##### Fan In

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit, GlorotUniformInit_FanIn
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser
import matplotlib.pyplot as plt

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100
weights_init = GlorotUniformInit_FanIn(rng=rng)
biases_init = ConstantInit(0.)

model_name = 'two_fan_in'

#Depth of the neural network

model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        LeakyReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        LeakyReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])
error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

    #Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, model_name, notebook=True)
# Out:
# ...
# Epoch 1: 2.1s to complete
#     error(train)=1.62e-01, acc(train)=9.53e-01, error(valid)=1.62e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 2.3s to complete
#     error(train)=1.06e-01, acc(train)=9.69e-01, error(valid)=1.24e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 2.3s to complete
#     error(train)=8.22e-02, acc(train)=9.75e-01, error(valid)=1.12e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 2.9s to complete
#     error(train)=6.25e-02, acc(train)=9.82e-01, error(valid)=1.04e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 2.7s to complete
#     error(train)=5.03e-02, acc(train)=9.86e-01, error(valid)=9.33e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 2.4s to complete
#     error(train)=4.60e-02, acc(train)=9.87e-01, error(valid)=9.70e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 2.5s to complete
# ...

# %% [markdown]
# ##### Fan Out

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit, GlorotUniformInit_FanOut
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser
import matplotlib.pyplot as plt

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100
weights_init = GlorotUniformInit_FanOut(rng=rng)
biases_init = ConstantInit(0.)

model_name = 'two_fan_out'

#Depth of the neural network

model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        LeakyReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        LeakyReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])
error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

    #Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, model_name, notebook=True)
# Out:
# ...
# Epoch 1: 1.5s to complete
#     error(train)=1.91e-01, acc(train)=9.42e-01, error(valid)=2.00e-01, acc(valid)=9.40e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 1.6s to complete
#     error(train)=1.23e-01, acc(train)=9.63e-01, error(valid)=1.53e-01, acc(valid)=9.53e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 1.5s to complete
#     error(train)=8.67e-02, acc(train)=9.74e-01, error(valid)=1.29e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 1.5s to complete
#     error(train)=7.74e-02, acc(train)=9.77e-01, error(valid)=1.32e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 2.6s to complete
#     error(train)=6.49e-02, acc(train)=9.79e-01, error(valid)=1.25e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 2.1s to complete
#     error(train)=4.54e-02, acc(train)=9.86e-01, error(valid)=1.17e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 1.4s to complete
# ...

# %% [markdown]
# ##### Fan In Out

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit, GlorotUniformInit_FanInOut
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser
import matplotlib.pyplot as plt

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100
weights_init = GlorotUniformInit_FanInOut(rng=rng)
biases_init = ConstantInit(0.)

model_name = 'two_fan_in_out'

#Depth of the neural network

model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        LeakyReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        LeakyReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])
error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

    #Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, model_name, notebook=True)
# Out:
# ...
# Epoch 1: 2.4s to complete
#     error(train)=1.55e-01, acc(train)=9.55e-01, error(valid)=1.61e-01, acc(valid)=9.55e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 1.9s to complete
#     error(train)=1.14e-01, acc(train)=9.65e-01, error(valid)=1.34e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 3.4s to complete
#     error(train)=7.72e-02, acc(train)=9.77e-01, error(valid)=1.15e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 2.6s to complete
#     error(train)=5.51e-02, acc(train)=9.84e-01, error(valid)=9.92e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 1.9s to complete
#     error(train)=4.80e-02, acc(train)=9.87e-01, error(valid)=9.75e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 2.4s to complete
#     error(train)=3.69e-02, acc(train)=9.90e-01, error(valid)=8.83e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 2.3s to complete
# ...

# %% [markdown]
# ### Playground

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser
import matplotlib.pyplot as plt


#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

#Array with all the type of models there are
model_name = 'sigmoid_over_100_iterations'

#Array with the mean performance for each function
mean_stats = []

#Run for each of the models

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, model_name, notebook=True)
# Out:
# ...
# Epoch 1: 2.3s to complete
#     error(train)=5.66e-01, acc(train)=8.56e-01, error(valid)=5.28e-01, acc(valid)=8.71e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 2.0s to complete
#     error(train)=3.69e-01, acc(train)=8.98e-01, error(valid)=3.41e-01, acc(valid)=9.07e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 2.0s to complete
#     error(train)=3.12e-01, acc(train)=9.10e-01, error(valid)=2.89e-01, acc(valid)=9.16e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 2.0s to complete
#     error(train)=2.85e-01, acc(train)=9.17e-01, error(valid)=2.66e-01, acc(valid)=9.25e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 2.0s to complete
#     error(train)=2.55e-01, acc(train)=9.27e-01, error(valid)=2.39e-01, acc(valid)=9.32e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 2.0s to complete
#     error(train)=2.32e-01, acc(train)=9.31e-01, error(valid)=2.20e-01, acc(valid)=9.36e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 2.0s to complete
# ...
